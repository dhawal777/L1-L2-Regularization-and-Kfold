# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from pylab import *
import matplotlib
import matplotlib.pyplot as plt
import copy

# %%
df=pd.read_csv("AdmissionDataset/data.csv")
df
X =df.drop(['Chance of Admit ','Serial No.'],axis=1)
y=df['Chance of Admit ']

# %% [markdown]
# *Standardizing consists in subtracting the mean and dividing by the standard deviation.*
# *The convention that you standardize predictions primarily exists so that the units of the regression coefficients are the same.*
# *when value are largely diffrent one is population and some other attribute is fraction*

# %%
X = (X - X.mean())/X.std()#normalize the data(z-mu)/(sigma)
# y=(y-y.mean())/y.std()
#kyuki actual y ke paas pahuchna hai isliye ,jhe y ko normalize karne ka koi reason nahi lag raha

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
features=['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']
my_data=pd.concat([X_train,y_train],axis=1)

# %%
X=X_train

# %%
ones = np.ones([X.shape[0],1])

# %%
X = np.concatenate((ones,X),axis=1)

# %% [markdown]
# *values converts it from pandas.core.frame.DataFrame to numpy.ndarray*

# %%
y
y=pd.DataFrame(y_train)
y=y.values

# %% [markdown]
# *basically assumed m=0 and c=0 for each independent variable intially*

# %% [markdown]
# *learning rate needed along with direction*

# %%
alpha = 0.01

# %%
def meanSquareError(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.square((y_true - y_pred)))

# %% [markdown]
# *no of times we have to iterate to minimize rms*

# %%
iters = 1000
lamda=1000
itr=0
lam=[]
error_list=[]
cost=[]

# %%
def gradientDescent(X,y,theta,iters,alpha,lamda):
    for i in range(iters):
        theta1=copy.deepcopy(theta)
        theta1[0][0]=0
        theta = theta - (alpha/len(X)) * (np.sum(X * (X @ theta.T - y), axis=0)+(theta1*lamda))
    return theta

# %%
i1=0
sum=0
for index,row in my_data.iterrows():
    alpha = 0.01
    iters = 1000
    theta = np.zeros([1,8])
    X_train1=my_data.drop(my_data.index[i1])
    X_test1= row[0:7]
    y_test1=row[7]
    X = X_train1.iloc[:,0:7]
    ones = np.ones([X.shape[0],1])
    X = np.concatenate((ones,X),axis=1)
    ylist = X_train1.iloc[:,7:8].values
    g = gradientDescent(X,ylist,theta,iters,alpha,1e-13)
    betaList=g[0]
    y=0
#     ones=np.ones([1,1])
#     print(ones)
#     print(X_test1)
    test1=[];
    test1.append(1)
    for w in X_test1:
        test1.append(w)
    X_tr2 = test1
    y_pred1=X_tr2@betaList
    print("Index Left out ",index,"error ",np.square(y_pred1-y_test1))
    sum=sum+np.square(y_pred1-y_test1)
    i1=i1+1
# Out:
# Index Left out  278 error  0.01924416617605872
# Index Left out  373 error  4.149364556405636e-05
# Index Left out  117 error  0.010293301581224823
# Index Left out  78 error  0.0021324930802274406
# Index Left out  1 error  0.0006439916299803614
# Index Left out  63 error  0.0007993125350115964
# Index Left out  264 error  0.00183360613865198
# Index Left out  71 error  0.001871954723819413
# Index Left out  349 error  0.009367561653298318
# Index Left out  291 error  0.00017389310444056966
# Index Left out  70 error  0.00023525286713666732
# Index Left out  134 error  0.002115346707263054
# Index Left out  281 error  0.000821542708809537
# Index Left out  405 error  0.00047479517616064816
# Index Left out  187 error  0.0018941943483880847
# Index Left out  377 error  0.007391321733731086
# Index Left out  105 error  0.0009961053330217466
# Index Left out  370 error  0.023982868106318462
# Index Left out  49 error  0.0019656161000099395
# Index Left out  424 error  0.005283572851106921
# Index Left out  341 error  0.0001271214452626989
# Index Left out  77 error  0.00014489827227826904
# Index Left out  382 error  0.006882959498159493
# Index Left out  442 error  1.1469248451886793e-08
# Index Left out  320 error  0.0006975427573327428
# Index Left out  273 error  0.00025382277686146975
# Index Left out  242 error  0.00025965423662184094
# Index Left out  368 error  0.0005849442843326305
# Index Left out  219 error  0.00017225133465174986
# Index Left out  315 error  0.0005997743992544025
# Index Left out  45 error  0.055353690401447574
# Index Left out  151 error  0.00014271144985278882
# Index Left out  375 error  0.0007425897734512929
# Index Left out  369 error  0.002864979808718664
# Index Left out  42 error  0.022265363901252434
# Index Left out  374 error  2.189496193204522e-06
# Index Left out  358 error  0.00012623686496668086
# Index Left out  21 error  0.00019880056048816178
# Index Left out  204 error  0.0009341622633417255
# Index Left out  314 error  0.0004429887538952439
# Index Left out  332 error  0.006822278101724217
# Index Left out  301 error  0.0010471017600538384
# Index Left out  350 error  0.0011547689655883237
# Index Left out  381 error  0.0033629086211396163
# Index Left out  213 error  0.0001144258617641615
# Index Left out  0 error  0.0007923290507198969
# Index Left out  420 error  0.0003803819254494032
# Index Left out  57 error  8.284889777430069e-05
# Index Left out  55 error  2.8223840334970616e-05
# Index Left out  256 error  0.0002491401605779848
# Index Left out  62 error  1.5890514853521926e-05
# Index Left out  168 error  0.001711311594255716
# Index Left out  59 error  0.0009815309376946747
# Index Left out  155 error  0.011317597867161208
# Index Left out  174 error  0.003896337912212464
# Index Left out  388 error  2.604017447821491e-05
# Index Left out  447 error  0.035691161966373404
# Index Left out  392 error  0.003438213869643225
# Index Left out  215 error  0.038884117020834025
# Index Left out  40 error  0.00015536128678517118
# Index Left out  431 error  8.231230378432062e-05
# Index Left out  366 error  0.001509620808813424
# Index Left out  353 error  0.0006083598543992917
# Index Left out  95 error  0.00016375143940715905
# Index Left out  140 error  0.0002064653114799674
# Index Left out  89 error  0.00030781315842441816
# Index Left out  446 error  9.596711176476068e-05
# Index Left out  163 error  0.0010340767858037934
# Index Left out  83 error  0.007276041568631372
# Index Left out  4 error  0.00233814060131134
# Index Left out  66 error  0.000274211168342527
# Index Left out  11 error  0.0001797093328934079
# Index Left out  148 error  0.0002890281705174529
# Index Left out  211 error  0.00019366736833250156
# Index Left out  157 error  0.005743479358207197
# Index Left out  298 error  0.0006535152680208894
# Index Left out  346 error  0.006634088680668193
# Index Left out  58 error  0.009459777465424724
# Index Left out  79 error  0.0005943657830896271
# Index Left out  144 error  0.00591069441977009
# Index Left out  169 error  0.0007684938239256481
# Index Left out  44 error  0.00012026926268750427
# Index Left out  235 error  0.016912563630882692
# Index Left out  319 error  0.0048563691250722634
# Index Left out  195 error  0.0008881312949726218
# Index Left out  327 error  0.0007893377919432664
# Index Left out  156 error  0.0021236507074821813
# Index Left out  137 error  0.02484898143731058
# Index Left out  190 error  0.00017854738075312785
# Index Left out  43 error  0.010487966844333363
# Index Left out  115 error  3.696334714250948e-05
# Index Left out  288 error  4.7142143717807234e-08
# Index Left out  438 error  0.0014705725276769957
# Index Left out  84 error  0.0001544207071101434
# Index Left out  328 error  0.0021228485075339854
# Index Left out  385 error  0.0009970228317773015
# Index Left out  64 error  0.0016918111312332913
# Index Left out  307 error  1.5948089692089253e-06
# Index Left out  10 error  0.0001737716664023133
# Index Left out  329 error  4.8381562656902215e-06
# Index Left out  142 error  0.0018673861237539062
# Index Left out  201 error  1.593520893218195e-05
# Index Left out  399 error  0.00034051085910356105
# Index Left out  305 error  0.013057700098635217
# Index Left out  417 error  0.0002566781937756435
# Index Left out  25 error  0.004606257582761539
# Index Left out  126 error  0.001583912591817903
# Index Left out  20 error  7.400770137444735e-07
# Index Left out  161 error  2.37122065218542e-05
# Index Left out  310 error  0.00016095947128965762
# Index Left out  363 error  0.018343682434593167
# Index Left out  30 error  0.0016523207131257421
# Index Left out  386 error  0.000576990886945407
# Index Left out  322 error  0.026921592597847353
# Index Left out  196 error  0.0003126327960473678
# Index Left out  400 error  0.0034602819743864404
# Index Left out  162 error  0.0007439150060823503
# Index Left out  294 error  8.728416183989123e-05
# Index Left out  146 error  0.0028097697562081275
# Index Left out  141 error  0.003157611950530829
# Index Left out  277 error  0.00012483093939951974
# Index Left out  76 error  0.0004981937266637084
# Index Left out  282 error  1.740224821147385e-05
# Index Left out  124 error  0.0006913326362359154
# Index Left out  445 error  0.003094417447099647
# Index Left out  184 error  0.00021013831338786103
# Index Left out  158 error  0.0001427034974338482
# Index Left out  110 error  0.002781672887549343
# Index Left out  361 error  2.969901844800435e-05
# Index Left out  128 error  0.0037531146493393884
# Index Left out  170 error  0.0013289080524365913
# Index Left out  429 error  0.0008968185232135414
# Index Left out  233 error  0.0005496276226633787
# Index Left out  209 error  0.0030563433246830916
# Index Left out  421 error  0.0004209588908704287
# Index Left out  178 error  0.0009344091138613375
# Index Left out  286 error  0.003192388133208225
# Index Left out  239 error  0.016211359995466038
# Index Left out  271 error  0.006737074916555871
# Index Left out  107 error  0.003765650551989866
# Index Left out  448 error  0.0008729593056480784
# Index Left out  423 error  0.0059135665716173475
# Index Left out  407 error  4.471716285442283e-06
# Index Left out  191 error  9.148823745141385e-05
# Index Left out  122 error  0.0012896562617663906
# Index Left out  290 error  0.002375286005003306
# Index Left out  220 error  1.3507592565363581e-05
# Index Left out  90 error  0.0003414975404191925
# Index Left out  192 error  0.0013368961198215366
# Index Left out  36 error  0.005790470532725045
# Index Left out  92 error  0.0009727659609255815
# Index Left out  285 error  0.0013812621707152925
# Index Left out  435 error  0.004349000698047191
# Index Left out  125 error  0.0008004902648852441
# Index Left out  333 error  0.057101132640583085
# Index Left out  188 error  0.003932414624449379
# Index Left out  279 error  0.024846572818174997
# Index Left out  243 error  2.139650800891442e-05
# Index Left out  426 error  0.018863432996596055
# Index Left out  143 error  0.001411505606997647
# Index Left out  292 error  1.0975868762606543e-05
# Index Left out  300 error  0.00016054960255680248
# Index Left out  317 error  0.0005015228469100766
# Index Left out  159 error  0.0004636465898192262
# Index Left out  415 error  0.00010200281872989668
# Index Left out  80 error  0.0017575615820525513
# Index Left out  359 error  4.39832323920301e-05
# Index Left out  449 error  0.0023728775461763062
# Index Left out  351 error  0.0003928854465296526
# Index Left out  17 error  0.0005663228958281251
# Index Left out  221 error  8.808136116781552e-05
# Index Left out  116 error  1.472387109934378e-05
# Index Left out  54 error  0.0004250625220844512
# Index Left out  231 error  0.0002066024470661618
# Index Left out  13 error  0.003069592195189409
# Index Left out  289 error  0.004256425703436274
# Index Left out  378 error  0.0003360656410985565
# Index Left out  251 error  0.0002923224913239927
# Index Left out  123 error  0.0018283665248660704
# Index Left out  402 error  0.0016721090894880105
# Index Left out  287 error  0.0011257375360330774
# Index Left out  262 error  1.684666133337041e-05
# Index Left out  33 error  9.929710390348016e-07
# Index Left out  244 error  0.0005353260804081876
# Index Left out  106 error  0.0028143210193808414
# Index Left out  202 error  0.00017439116706322928
# Index Left out  336 error  0.0002182032620807268
# Index Left out  150 error  0.007909288927087097
# Index Left out  344 error  0.000670828869697932
# Index Left out  210 error  0.00255473727230153
# Index Left out  411 error  0.00661470261425878
# Index Left out  72 error  0.004773850888369443
# Index Left out  267 error  0.00013165107750427453
# Index Left out  270 error  8.064252982658078e-05
# Index Left out  427 error  0.0009012025930805494
# Index Left out  234 error  0.00020555368154748035
# Index Left out  230 error  0.0076295291333588885
# Index Left out  16 error  0.0007555060047452159
# Index Left out  280 error  0.008742982773973512
# Index Left out  111 error  0.001094251711370974
# Index Left out  397 error  0.00026694004126553815
# Index Left out  100 error  0.022251610152211356
# Index Left out  331 error  0.00527905208867813
# Index Left out  175 error  0.000836198307946873
# Index Left out  5 error  0.00011227946784444744
# Index Left out  101 error  0.00028254691969736796
# Index Left out  218 error  0.0007606463434106539
# Index Left out  109 error  0.0017697004383164267
# Index Left out  120 error  1.5621902191076395e-05
# Index Left out  39 error  0.00011837261456082028
# Index Left out  240 error  0.004686424053003398
# Index Left out  412 error  0.0009043089601487838
# Index Left out  261 error  0.0009287663754894921
# Index Left out  179 error  0.01597286858368601
# Index Left out  296 error  0.0029966868659481775
# Index Left out  232 error  0.00021123799043416946
# Index Left out  121 error  0.0033567877315432053
# Index Left out  443 error  0.001418912376420719
# Index Left out  441 error  0.00657595541704142
# Index Left out  205 error  0.00019981626226944568
# Index Left out  34 error  0.001975276676869996
# Index Left out  247 error  0.009730059851890509
# Index Left out  108 error  0.00044957077667763035
# Index Left out  237 error  0.0005588412125929297
# Index Left out  257 error  0.013607493608134128
# Index Left out  91 error  0.0005557523703834449
# Index Left out  153 error  0.0010311209879786925
# Index Left out  433 error  0.0013915919905004234
# Index Left out  348 error  0.0002216428450436168
# Index Left out  275 error  3.227833933429353e-05
# Index Left out  207 error  2.170905683107855e-06
# Index Left out  225 error  0.001254135931747342
# Index Left out  67 error  4.2552916547647486e-05
# Index Left out  172 error  0.00017565145373042633
# Index Left out  88 error  0.0027945002450169123
# Index Left out  299 error  0.00023070270764620132
# Index Left out  254 error  0.0012125364699825973
# Index Left out  35 error  0.03706905182187106
# Index Left out  330 error  0.00010549556548093273
# Index Left out  284 error  0.002236342775309096
# Index Left out  229 error  0.003314097464842176
# Index Left out  119 error  1.0971949915877793e-05
# Index Left out  276 error  0.004206778084261894
# Index Left out  182 error  0.000982929944754426
# Index Left out  340 error  6.873206297000361e-06
# Index Left out  223 error  1.8930830418778165e-05
# Index Left out  12 error  0.00034572657177782797
# Index Left out  14 error  3.670482635450573e-05
# Index Left out  81 error  0.006105964420616608
# Index Left out  354 error  0.0007777901865381717
# Index Left out  75 error  0.00029916813518927557
# Index Left out  56 error  0.003450391500784916
# Index Left out  338 error  0.00018662143723754583
# Index Left out  8 error  0.005999906087481716
# Index Left out  3 error  0.0007117284050528367
# Index Left out  2 error  0.0029028061533568103
# Index Left out  104 error  0.03108302988565163
# Index Left out  339 error  0.00016374301808787201
# Index Left out  393 error  0.021545740186119194
# Index Left out  160 error  0.0009583910466383999
# Index Left out  384 error  0.0020944210659716465
# Index Left out  112 error  0.0021352079626072553
# Index Left out  152 error  0.00039507037779009724
# Index Left out  263 error  0.0002683234743954555
# Index Left out  186 error  0.002290898472985268
# Index Left out  228 error  0.0007351617538739035
# Index Left out  203 error  0.0007414037058379356
# Index Left out  145 error  0.0008168862261595067
# Index Left out  308 error  0.0064466728280391985
# Index Left out  342 error  0.0001094344328805579
# Index Left out  379 error  0.00018029178912197662
# Index Left out  38 error  0.0012346552640197551
# Index Left out  28 error  7.593242922640225e-05
# Index Left out  334 error  9.906336136098857e-05
# Index Left out  226 error  0.0008134979126373943
# Index Left out  418 error  0.002562926183619651
# Index Left out  323 error  0.004311187670879241
# Index Left out  419 error  0.0036555256993394476
# Index Left out  18 error  4.608268276493032e-05
# Index Left out  183 error  0.012980005304759146
# Index Left out  241 error  2.319931481410701e-05
# Index Left out  23 error  0.006474383223225143
# Index Left out  272 error  0.0005120244078527952
# Index Left out  337 error  0.00026637222598205747
# Index Left out  362 error  0.008852129009046496
# Index Left out  97 error  0.0007468977206501211
# Index Left out  437 error  3.058619884171355e-06
# Index Left out  258 error  0.00012026397554133937
# Index Left out  245 error  0.0010150785164877362
# Index Left out  335 error  5.171689086863669e-05
# Index Left out  86 error  0.0006309160978299354
# Index Left out  439 error  0.007766920567103441
# Index Left out  356 error  0.004301330154071782
# Index Left out  94 error  4.1444478116072956e-07
# Index Left out  249 error  0.0006396449949892131
# Index Left out  391 error  0.0031303293551174453
# Index Left out  27 error  0.008046542835081149
# Index Left out  352 error  0.0001548557239443972
# Index Left out  416 error  0.0003325232978060397
# Index Left out  222 error  0.0006199181779905456
# Index Left out  31 error  4.085906243789031e-06
# Index Left out  61 error  0.001905200041712799
# Index Left out  365 error  0.0032954654049926484
# Index Left out  176 error  7.63764074054191e-05
# Index Left out  189 error  0.02558825899370613
# Index Left out  154 error  3.606931458317634e-05
# Index Left out  318 error  0.0009483319170506718
# Index Left out  297 error  0.0006456188470062085
# Index Left out  118 error  0.0012145756075392013
# Index Left out  7 error  0.007807310796987377
# Index Left out  357 error  0.00197741545044708
# Index Left out  139 error  1.39576916918165e-06
# Index Left out  74 error  2.253473079351865e-07
# Index Left out  193 error  8.221619813583803e-05
# Index Left out  68 error  0.0019281322128895469
# Index Left out  406 error  0.00029594618473735074
# Index Left out  99 error  0.007077079704150635
# Index Left out  65 error  1.3187150654319822e-05
# Index Left out  260 error  0.0001412796856427639
# Index Left out  383 error  0.044068382459274
# Index Left out  53 error  0.003884302422155688
# Index Left out  24 error  0.000163283048466518
# Index Left out  199 error  0.00036951930311904664
# Index Left out  103 error  0.004814573065217887
# Index Left out  180 error  0.013528037262553454
# Index Left out  6 error  0.0004506394448266163
# Index Left out  217 error  0.00082718372155175
# Index Left out  403 error  5.387497280164869e-05
# Index Left out  135 error  0.0004669772452759862
# Index Left out  389 error  0.005644591620395428
# Index Left out  93 error  0.001049419974333409
# Index Left out  51 error  0.002792648550620302
# Index Left out  414 error  0.003174763064123481
# Index Left out  293 error  0.00013433971244906725
# Index Left out  324 error  1.5757132626067523e-05
# Index Left out  252 error  0.000773306787994142
# Index Left out  47 error  0.0008749237091888618
# Index Left out  131 error  0.0015468307516544467
# Index Left out  60 error  0.00012103008121683726
# Index Left out  395 error  0.0013616397931179428
# Index Left out  253 error  0.0012655692355226765
# Index Left out  283 error  0.005410061206761947
# Index Left out  216 error  0.009504814041735931
# Index Left out  408 error  0.0005898165185108556
# Index Left out  259 error  7.133025030443628e-06
# Index Left out  434 error  0.0015209640846349216
# Index Left out  208 error  0.0005201211284007005
# Index Left out  41 error  7.705008827389467e-05
# Index Left out  387 error  0.011711403035771693
# Index Left out  167 error  0.0007930164253030917
# Index Left out  367 error  0.001045109936992516
# Index Left out  250 error  0.00631395305369499
# Index Left out  185 error  0.004326908391646842
# Index Left out  198 error  0.0008012578546131825
# Index Left out  425 error  0.0004614387884792882
# Index Left out  326 error  0.0009658941892291945
# Index Left out  303 error  1.9081377248450357e-06
# Index Left out  133 error  0.01886903047006928
# Index Left out  224 error  0.0007191781318711582
# Index Left out  37 error  0.0035625498885553165

# %%
print("mean_error Loove :",sum/360)
# Out:
# mean_error Loove : 0.003478793331386119
